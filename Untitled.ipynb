# %%
# !pwd
# Out:
# /home/tae/dev_ws/kudos12_2023/yolo_setting/yolov5_new

# %%
# !python3 train.py --img 384 --batch 32 --epochs 160 --data coco128.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name yolov5_s
# Out:
# train: weights=yolov5s.pt, cfg=./models/yolov5s.yaml, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=160, batch_size=32, imgsz=384, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5_s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-215-ga6659d0 Python-3.8.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5938MiB)
#
# ...
